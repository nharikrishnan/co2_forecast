# %% [markdown]
# ## Forecasting CO2 levels using Holt winters

# %% [markdown]
# <b><font size = 4>Objective</b>
# * To analyze and forecast the atmospheric CO2 using holtwinters

# %%
# Loading the required modules
import pandas as pd
import numpy as np
from statsmodels.tsa.api import ExponentialSmoothing
from statsmodels.tsa.seasonal import seasonal_decompose
import statsmodels.api as sm

import matplotlib.pyplot as plt

# %% [markdown]
# ### Loding the dataset from statsmodels

# %%
# Loading the dataset
co2 = sm.datasets.co2.load_pandas()
df_co2 = co2.data
print(df_co2.head())
# Out:
#               co2
# 1958-03-29  316.1
# 1958-04-05  317.3
# 1958-04-12  317.6
# 1958-04-19  317.5
# 1958-04-26  316.4

# %%
plt.figure(figsize = (16,8))
plt.plot(df_co2, label = 'atmospheric CO2')
plt.xlabel('year')
plt.ylabel('CO2 level')
plt.legend(loc = 'best')
plt.show()

# %% [markdown]
# <p> <font size = 3> Clearly there is an upward trend and seasonality

# %%
#Checking for missing values 
print(df_co2.isna().sum())
# Out:
# co2    59
# dtype: int64

# %%
#treating na values
#replacing the na value with previour terms value
df_co2.fillna(df_co2.bfill(), inplace = True)

# %%
#splitting the data into Train and Test datasets
df_co2.reset_index(inplace = True)
df_co2.columns = ['date', 'co2']
df_co2['date'] = pd.to_datetime(df_co2['date'])
df_co2.min(), df_co2.max()
# Out:
# (date    1958-03-29 00:00:00
#  co2                     313
#  dtype: object,
#  date    2001-12-29 00:00:00
#  co2                   373.9
#  dtype: object)

# %% [markdown]
# <p><font size=3> For testing, the last three years data is used.

# %%
# splitting the data trainning and testing
train = df_co2[df_co2['date'] <'1998-01-01']

#last 3 years data for testing
test = df_co2[df_co2['date']>='1998-01-01']
train.set_index('date', inplace=True)
test.set_index('date', inplace=True)

# %% [markdown]
# ### Analyzing the data

# %%
# seasonal decompose- visualizing the trend, seasonal, and residual component
ts_decompose = seasonal_decompose(train, freq = 52)
trend = ts_decompose.trend
seasonal = ts_decompose.seasonal
residual = ts_decompose.resid

#training data
plt.figure(figsize = (30,20))
plt.subplot(411)
plt.plot(train, label = 'Original')
plt.legend(loc = 'best')

#Trend Component
plt.subplot(412)
plt.plot(trend, label ='Trend')
plt.legend(loc = 'best')

#Seasonal Component
plt.subplot(413)
plt.plot(seasonal, label = 'Seasonal')
plt.legend(loc = 'best')

#Residual Component
plt.subplot(414)
plt.plot(residual, label = 'residual')
plt.legend(loc = 'best')

plt.tight_layout()
plt.show()
# Out:
# C:\Users\hkpat\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: the 'freq'' keyword is deprecated, use 'period' instead

# %% [markdown]
# clearly there is weekly seasonal component

# %% [markdown]
# ### Forecasting using holt-winters

# %% [markdown]
# <p> <font size=3>Here, Mulitplicative method is used. There is very little variation, even if we use a Additive Seasonality method for this dataset<br>
# The seasonal_periods is 52, since we are considering weekly seasonality.<br>
# The forecast and the actual results is plotted below.

# %%
fit_forecast = ExponentialSmoothing(np.asarray(train['co2']), seasonal_periods=52, seasonal = 'mul', trend = 'mul').fit()
y_pred = test.copy()

#forecast
y_pred['holt_winter'] = fit_forecast.forecast(len(test['co2']))

#plotting
plt.figure(figsize = (15, 6))
plt.plot(train['co2'], label='train')
plt.plot(test['co2'], label='Actual')
plt.plot(y_pred['holt_winter'], label = 'Forecast')

plt.legend(loc = 'best')

plt.show()
# Out:
# C:\Users\hkpat\Anaconda3\lib\site-packages\statsmodels\tsa\holtwinters.py:725: RuntimeWarning: invalid value encountered in less_equal
#   loc = initial_p <= lb
# C:\Users\hkpat\Anaconda3\lib\site-packages\statsmodels\tsa\holtwinters.py:731: RuntimeWarning: invalid value encountered in greater_equal
#   loc = initial_p >= ub
# C:\Users\hkpat\Anaconda3\lib\site-packages\statsmodels\tsa\holtwinters.py:744: ConvergenceWarning: Optimization failed to converge. Check mle_retvals.
#   ConvergenceWarning)

# %%
# checking the root mean squared error
from sklearn.metrics import mean_squared_error
error = np.sqrt(mean_squared_error(test['co2'], y_pred['holt_winter']))
print(error)
# Out:
# 1.1857857890900154

# %%
train['co2'].std()
# Out:
# 15.078869587408244

# %%
#plotting the difference in forecast
diff = test['co2'] - y_pred['holt_winter']
plt.plot(diff)
